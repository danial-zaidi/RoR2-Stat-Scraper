# %%
import os
import xml.etree.ElementTree as ET

folder_path = 'path_to_your_folder'
names_file_path = './StatParsingList.txt'

# Read the names of the XML files from the text file
with open(names_file_path, 'r') as file:
    xml_filenames = file.read().splitlines()


data = []
# Out:
# ['gameModeName', 'gameEnding', 'seed', 'runStartTimeUtc', 'snapshotTimeUtc', 'snapshotRunTime', 'runStopwatchValue', 'ruleBook', 'name', 'bodyName', 'killerBodyName', 'isDead', 'totalGamesPlayed', 'totalTimeAlive', 'totalKills', 'totalMinionKills', 'totalDamageDealt', 'totalDamageTaken', 'totalHealthHealed', 'highestDamageDealt', 'highestLevel', 'totalGoldCollected', 'maxGoldCollected', 'totalDistanceTraveled', 'totalItemsCollected', 'highestItemsCollected', 'totalStagesCompleted', 'highestStagesCompleted', 'totalPurchases', 'highestPurchases', 'totalGoldPurchases', 'highestGoldPurchases', 'totalLunarPurchases', 'highestLunarPurchases', 'totalTier1Purchases', 'highestTier1Purchases', 'totalDronesPurchased', 'totalTurretsPurchased', 'totalGreenSoupsPurchased', 'totalEliteKills', 'totalTeleporterBossKillsWitnessed', 'totalMaulingRockKills', 'totalTimeAlive.Bandit2Body', 'longestRun.Bandit2Body', 'damageDealtTo.BeetleBody', 'damageDealtTo.BeetleGuardAllyBody', 'damageDealtTo.BeetleGuard
# ...

# %%
# Iterate through each XML file name
for xml_filename in xml_filenames:
    xml_file_path = os.path.join(folder_path, xml_filename + '.xml')
    
    # Check if the file exists
    if os.path.exists(xml_file_path):
        # Parse the XML file
        tree = ET.parse(xml_file_path)
        root = tree.getroot()

        # Extract data from the XML structure
        version = root.find('version').text
        run_guid = root.find('runGuid').text
        game_mode_name = root.find('gameModeName').text
        game_ending = root.find('gameEnding').text
        seed = root.find('seed').text
        run_start_time_utc = root.find('runStartTimeUtc').text
        snapshot_time_utc = root.find('snapshotTimeUtc').text
        snapshot_run_time = root.find('snapshotRunTime').text
        run_stopwatch_value = root.find('runStopwatchValue').text
        rule_book = root.find('ruleBook').text

        player_infos = []
        for player_info in root.findall('./playerInfos/PlayerInfo'):
            name = player_info.find('name').text
            body_name = player_info.find('bodyName').text
            killer_body_name = player_info.find('killerBodyName').text
            is_dead = player_info.find('isDead').text
            totalGamesPlayed = player_info.find('totalGamesPlayed').text
            totalGamesPlayed = player_info.find('totalGamesPlayed').text
            totalTimeAlive = player_info.find('totalTimeAlive').text
            totalKills = player_info.find('totalKills').text
            totalMinionKills = player_info.find('totalMinionKills').text
            totalDamageDealt = player_info.find('totalDamageDealt').text
            totalDamageTaken = player_info.find('totalDamageTaken').text
            totalHealthHealed = player_info.find('totalHealthHealed').text
            highestDamageDealt = player_info.find('highestDamageDealt').text
            highestLevel = player_info.find('highestLevel').text
            totalGoldCollected = player_info.find('totalGoldCollected').text
            maxGoldCollected = player_info.find('maxGoldCollected').text
            totalDistanceTraveled = player_info.find('totalDistanceTraveled').text
            totalItemsCollected = player_info.find('totalItemsCollected').text
            highestItemsCollected = player_info.find('highestItemsCollected').text
            totalStagesCompleted = player_info.find('totalStagesCompleted').text
            highestStagesCompleted = player_info.find('highestStagesCompleted').text
            totalPurchases = player_info.find('totalPurchases').text
            highestPurchases = player_info.find('highestPurchases').text
            totalGoldPurchases = player_info.find('totalGoldPurchases').text
            highestGoldPurchases = player_info.find('highestGoldPurchases').text
            totalLunarPurchases = player_info.find('totalLunarPurchases').text
            highestLunarPurchases = player_info.find('highestLunarPurchases').text
            totalTier1Purchases = player_info.find('totalTier1Purchases').text
            highestTier1Purchases = player_info.find('highestTier1Purchases').text
            totalDronesPurchased = player_info.find('totalDronesPurchased').text
            totalTurretsPurchased = player_info.find('totalTurretsPurchased').text
            totalGreenSoupsPurchased = player_info.find('totalGreenSoupsPurchased').text
            totalEliteKills = player_info.find('totalEliteKills').text
            totalTeleporterBossKillsWitnessed = player_info.find('totalTeleporterBossKillsWitnessed').text
            totalMaulingRockKills = player_info.find('totalMaulingRockKills').text
            totalTimeAliveBandit2Body = player_info.find('totalTimeAlive.Bandit2Body').text
            longestRunBandit2Body = player_info.find('longestRun.Bandit2Body').text
            damageDealtToBeetleBody = player_info.find('damageDealtTo.BeetleBody').text
            damageDealtToBeetleGuardAllyBody = player_info.find('damageDealtTo.BeetleGuardAllyBody').text
            damageDealtToBeetleGuardBody = player_info.find('damageDealtTo.BeetleGuardBody').text
            damageDealtToBeetleQueen2Bod = player_info.find('damageDealtTo.BeetleQueen2Bod').text
            damageDealtToBellBody = player_info.find('damageDealtTo.BellBody').text
            damageDealtToBrotherBody = player_info.find('damageDealtTo.BrotherBody').text
            damageDealtToBrotherHurtBody = player_info.find('damageDealtTo.BrotherHurtBody').text
            damageDealtToClayBossBody = player_info.find('damageDealtTo.ClayBossBody').text
            damageDealtToClayBruiserBody = player_info.find('damageDealtTo.ClayBruiserBody').text
            damageDealtToExplosivePotDestructibleBody = player_info.find('damageDealtTo.ExplosivePotDestructibleBody').text
            damageDealtToGolemBody = player_info.find('damageDealtTo.GolemBody').text
            damageDealtToGrandParentBody = player_info.find('damageDealtTo.GrandParentBody').text
            damageDealtToGravekeeperBody = player_info.find('damageDealtTo.GravekeeperBody').text
            damageDealtToGravekeeperTrackingFireball = player_info.find('damageDealtTo.GravekeeperTrackingFireball').text
            damageDealtToGreaterWispBody = player_info.find('damageDealtTo.GreaterWispBody').text
            damageDealtToImpBody = player_info.find('damageDealtTo.ImpBody').text
            damageDealtToImpBossBody = player_info.find('damageDealtTo.ImpBossBody').text
            damageDealtToJellyfishBody = player_info.find('damageDealtTo.JellyfishBody').text
            damageDealtToLemurianBody = player_info.find('damageDealtTo.LemurianBody').text
            damageDealtToLemurianBruiserBody = player_info.find('damageDealtTo.LemurianBruiserBody').text
            damageDealtToLunarExploderBody = player_info.find('damageDealtTo.LunarExploderBody').text
            damageDealtToLunarGolemBody = player_info.find('damageDealtTo.LunarGolemBody').text
            damageDealtToLunarWispBody = player_info.find('damageDealtTo.LunarWispBody').text
            damageDealtToMagmaWormBody = player_info.find('damageDealtTo.MagmaWormBody').text
            damageDealtToMiniMushroomBody = player_info.find('damageDealtTo.MiniMushroomBody').text
            damageDealtToNullifierBody = player_info.find('damageDealtTo.NullifierBody').text
            damageDealtToParentBody = player_info.find('damageDealtTo.ParentBody').text
            damageDealtToRoboBallBossBody = player_info.find('damageDealtTo.RoboBallBossBody').text
            damageDealtToRoboBallMiniBody = player_info.find('damageDealtTo.RoboBallMiniBody').text
            damageDealtToSMMaulingRockLarge = player_info.find('damageDealtTo.SMMaulingRockLarge').text
            damageDealtToSMMaulingRockMedium = player_info.find('damageDealtTo.SMMaulingRockMedium').text
            damageDealtToScavBody = player_info.find('damageDealtTo.ScavBody').text
            damageDealtToShopkeeperBody = player_info.find('damageDealtTo.ShopkeeperBody').text
            damageDealtToSuperRoboBallBossBody = player_info.find('damageDealtTo.SuperRoboBallBossBody').text
            damageDealtToTitanBody = player_info.find('damageDealtTo.TitanBody').text
            damageDealtToUrchinTurretBody = player_info.find('damageDealtTo.UrchinTurretBody').text
            damageDealtToVagrantBody = player_info.find('damageDealtTo.VagrantBody').text
            damageDealtToVagrantTrackingBomb = player_info.find('damageDealtTo.VagrantTrackingBomb').text
            damageDealtToVultureBody = player_info.find('damageDealtTo.VultureBody').text
            damageDealtToVultureEggBody = player_info.find('damageDealtTo.VultureEggBody').text
            damageDealtToWispBody = player_info.find('damageDealtTo.WispBody').text
            damageDealtAsBandit2Body = player_info.find('damageDealtAs.Bandit2Body').text
            minionDamageDealtAsBandit2Body = player_info.find('minionDamageDealtAs.Bandit2Body').text
            damageTakenFromArtifactShellBody = player_info.find('damageTakenFrom.ArtifactShellBody').text
            damageTakenFromBeetleBody = player_info.find('damageTakenFrom.BeetleBody').text
            damageTakenFromBeetleGuardBody = player_info.find('damageTakenFrom.BeetleGuardBody').text
            damageTakenFromBellBody = player_info.find('damageTakenFrom.BellBody').text
            damageTakenFromBrotherBody = player_info.find('damageTakenFrom.BrotherBody').text
            damageTakenFromBrotherHauntBody = player_info.find('damageTakenFrom.BrotherHauntBody').text
            damageTakenFromBrotherHurtBody = player_info.find('damageTakenFrom.BrotherHurtBody').text
            damageTakenFromClayBossBody = player_info.find('damageTakenFrom.ClayBossBody').text
            damageTakenFromClayBruiserBody = player_info.find('damageTakenFrom.ClayBruiserBody').text
            damageTakenFromGolemBody = player_info.find('damageTakenFrom.GolemBody').text
            damageTakenFromGravekeeperBody = player_info.find('damageTakenFrom.GravekeeperBody').text
            damageTakenFromGreaterWispBody = player_info.find('damageTakenFrom.GreaterWispBody').text
            damageTakenFromJellyfishBody = player_info.find('damageTakenFrom.JellyfishBody').text
            damageTakenFromLemurianBody = player_info.find('damageTakenFrom.LemurianBody').text
            damageTakenFromLemurianBruiserBody = player_info.find('damageTakenFrom.LemurianBruiserBody').text
            damageTakenFromLunarExploderBody = player_info.find('damageTakenFrom.LunarExploderBody').text
            damageTakenFromLunarWispBody = player_info.find('damageTakenFrom.LunarWispBody').text
            damageTakenFromMagmaWormBody = player_info.find('damageTakenFrom.MagmaWormBody').text
            damageTakenFromMiniMushroomBody = player_info.find('damageTakenFrom.MiniMushroomBody').text
            damageTakenFromNullifierBody = player_info.find('damageTakenFrom.NullifierBody').text
            damageTakenFromParentBody = player_info.find('damageTakenFrom.ParentBody').text
            damageTakenFromRoboBallMiniBody = player_info.find('damageTakenFrom.RoboBallMiniBody').text
            damageTakenFromScavBody = player_info.find('damageTakenFrom.ScavBody').text
            damageTakenFromSuperRoboBallBossBody = player_info.find('damageTakenFrom.SuperRoboBallBossBody').text
            damageTakenFromVagrantBody = player_info.find('damageTakenFrom.VagrantBody').text
            damageTakenFromVultureBody = player_info.find('damageTakenFrom.VultureBody').text
            damageTakenFromWispBody = player_info.find('damageTakenFrom.WispBody').text
            damageTakenAsBandit2Body = player_info.find('damageTakenAs.Bandit2Body').text
            killsAgainstBeetleBody = player_info.find('killsAgainst.BeetleBody').text
            killsAgainstBeetleGuardBody = player_info.find('killsAgainst.BeetleGuardBody').text
            killsAgainstBeetleQueen2Body = player_info.find('killsAgainst.BeetleQueen2Body').text
            killsAgainstBellBody = player_info.find('killsAgainst.BellBody').text
            killsAgainstClayBossBody = player_info.find('killsAgainst.ClayBossBody').text
            killsAgainstClayBruiserBody = player_info.find('killsAgainst.ClayBruiserBody').text
            killsAgainstExplosivePotDestructibleBody = player_info.find('killsAgainst.ExplosivePotDestructibleBody').text
            killsAgainstGolemBody = player_info.find('killsAgainst.GolemBody').text
            killsAgainstGrandParentBody = player_info.find('killsAgainst.GrandParentBody').text
            killsAgainstGravekeeperBody = player_info.find('killsAgainst.GravekeeperBody').text
            killsAgainstGreaterWispBody = player_info.find('killsAgainst.GreaterWispBody').text
            killsAgainstImpBody = player_info.find('killsAgainst.ImpBody').text
            killsAgainstImpBossBody = player_info.find('killsAgainst.ImpBossBody').text
            killsAgainstJellyfishBody = player_info.find('killsAgainst.JellyfishBody').text
            killsAgainstLemurianBody = player_info.find('killsAgainst.LemurianBody').text
            killsAgainstLemurianBruiserBody = player_info.find('killsAgainst.LemurianBruiserBody').text
            killsAgainstLunarExploderBody = player_info.find('killsAgainst.LunarExploderBody').text
            killsAgainstLunarGolemBody = player_info.find('killsAgainst.LunarGolemBody').text
            killsAgainstLunarWispBody = player_info.find('killsAgainst.LunarWispBody').text
            killsAgainstMagmaWormBody = player_info.find('killsAgainst.MagmaWormBody').text
            killsAgainstMiniMushroomBody = player_info.find('killsAgainst.MiniMushroomBody').text
            killsAgainstNullifierBody = player_info.find('killsAgainst.NullifierBody').text
            killsAgainstParentBody = player_info.find('killsAgainst.ParentBody').text
            killsAgainstRoboBallBossBody = player_info.find('killsAgainst.RoboBallBossBody').text
            killsAgainstRoboBallMiniBody = player_info.find('killsAgainst.RoboBallMiniBody').text
            killsAgainstSMMaulingRockLarge = player_info.find('killsAgainst.SMMaulingRockLarge').text
            killsAgainstSMMaulingRockMedium = player_info.find('killsAgainst.SMMaulingRockMedium').text
            killsAgainstScavBody = player_info.find('killsAgainst.ScavBody').text
            killsAgainstSuperRoboBallBossBody = player_info.find('killsAgainst.SuperRoboBallBossBody').text
            killsAgainstTitanBody = player_info.find('killsAgainst.TitanBody').text
            killsAgainstUrchinTurretBody = player_info.find('killsAgainst.UrchinTurretBody').text
            killsAgainstVagrantBody = player_info.find('killsAgainst.VagrantBody').text
            killsAgainstVagrantTrackingBomb = player_info.find('killsAgainst.VagrantTrackingBomb').text
            killsAgainstVultureBody = player_info.find('killsAgainst.VultureBody').text
            killsAgainstVultureEggBody = player_info.find('killsAgainst.VultureEggBody').text
            killsAgainstWispBody = player_info.find('killsAgainst.WispBody').text
            killsAgainstEliteBeetleBody = player_info.find('killsAgainstElite.BeetleBody').text
            killsAgainstEliteBellBody = player_info.find('killsAgainstElite.BellBody').text
            killsAgainstEliteGolemBody = player_info.find('killsAgainstElite.GolemBody').text
            killsAgainstEliteImpBody = player_info.find('killsAgainstElite.ImpBody').text
            killsAgainstEliteJellyfishBody = player_info.find('killsAgainstElite.JellyfishBody').text
            killsAgainstEliteLemurianBody = player_info.find('killsAgainstElite.LemurianBody').text
            killsAgainstEliteLunarExploderBody = player_info.find('killsAgainstElite.LunarExploderBody').text
            killsAgainstEliteMiniMushroomBody = player_info.find('killsAgainstElite.MiniMushroomBody').text
            killsAgainstEliteVultureBody = player_info.find('killsAgainstElite.VultureBody').text
            killsAgainstEliteWispBody = player_info.find('killsAgainstElite.WispBody').text
            killsAsBandit2Body = player_info.find('killsAs.Bandit2Body').text
            minionKillsAsBandit2Body = player_info.find('minionKillsAs.Bandit2Body').text
            timesPickedBandit2Body = player_info.find('timesPicked.Bandit2Body').text
            totalCollectedAlienHead = player_info.find('totalCollected.AlienHead').text
            totalCollectedArmorPlate = player_info.find('totalCollected.ArmorPlate').text
            totalCollectedArmorReductionOnHit = player_info.find('totalCollected.ArmorReductionOnHit').text
            totalCollectedArtifactKey = player_info.find('totalCollected.ArtifactKey').text
            totalCollectedBarrierOnKill = player_info.find('totalCollected.BarrierOnKill').text
            totalCollectedBear = player_info.find('totalCollected.Bear').text
            totalCollectedBeetleGland = player_info.find('totalCollected.BeetleGland').text
            totalCollectedBleedOnHit = player_info.find('totalCollected.BleedOnHit').text
            totalCollectedBonusGoldPackOnKill = player_info.find('totalCollected.BonusGoldPackOnKill').text
            totalCollectedBossDamageBonus = player_info.find('totalCollected.BossDamageBonus').text
            totalCollectedChainLightning = player_info.find('totalCollected.ChainLightning').text
            totalCollectedCritGlasses = player_info.find('totalCollected.CritGlasses').text
            totalCollectedCrowbar = player_info.find('totalCollected.Crowbar').text
            totalCollectedDeathMark = player_info.find('totalCollected.DeathMark').text
            totalCollectedDrizzlePlayerHelper = player_info.find('totalCollected.DrizzlePlayerHelper').text
            totalCollectedEquipmentMagazine = player_info.find('totalCollected.EquipmentMagazine').text
            totalCollectedExecuteLowHealthElite = player_info.find('totalCollected.ExecuteLowHealthElite').text
            totalCollectedFallBoots = player_info.find('totalCollected.FallBoots').text
            totalCollectedFeather = player_info.find('totalCollected.Feather').text
            totalCollectedFlatHealth = player_info.find('totalCollected.FlatHealth').text
            totalCollectedHeadHunter = player_info.find('totalCollected.HeadHunter').text
            totalCollectedHealWhileSafe = player_info.find('totalCollected.HealWhileSafe').text
            totalCollectedHoof = player_info.find('totalCollected.Hoof').text
            totalCollectedIcicle = player_info.find('totalCollected.Icicle').text
            totalCollectedIgniteOnKill = player_info.find('totalCollected.IgniteOnKill').text
            totalCollectedJumpBoost = player_info.find('totalCollected.JumpBoost').text
            totalCollectedMedkit = player_info.find('totalCollected.Medkit').text
            totalCollectedMissile = player_info.find('totalCollected.Missile').text
            totalCollectedMushroom = player_info.find('totalCollected.Mushroom').text
            totalCollectedNearbyDamageBonus = player_info.find('totalCollected.NearbyDamageBonus').text
            totalCollectedNovaOnLowHealth = player_info.find('totalCollected.NovaOnLowHealth').text
            totalCollectedPersonalShield = player_info.find('totalCollected.PersonalShield').text
            totalCollectedPhasing = player_info.find('totalCollected.Phasing').text
            totalCollectedScrapWhite = player_info.find('totalCollected.ScrapWhite').text
            totalCollectedSeed = player_info.find('totalCollected.Seed').text
            totalCollectedSlowOnHit = player_info.find('totalCollected.SlowOnHit').text
            totalCollectedSprintArmor = player_info.find('totalCollected.SprintArmor').text
            totalCollectedSprintBonus = player_info.find('totalCollected.SprintBonus').text
            totalCollectedSprintOutOfCombat = player_info.find('totalCollected.SprintOutOfCombat').text
            totalCollectedStickyBomb = player_info.find('totalCollected.StickyBomb').text
            totalCollectedStunChanceOnHit = player_info.find('totalCollected.StunChanceOnHit').text
            totalCollectedSyringe = player_info.find('totalCollected.Syringe').text
            totalCollectedTPHealingNova = player_info.find('totalCollected.TPHealingNova').text
            totalCollectedThorns = player_info.find('totalCollected.Thorns').text
            totalCollectedTooth = player_info.find('totalCollected.Tooth').text
            totalCollectedTreasureCache = player_info.find('totalCollected.TreasureCache').text
            totalCollectedWardOnLevel = player_info.find('totalCollected.WardOnLevel').text
            highestCollectedAlienHead = player_info.find('highestCollected.AlienHead').text
            highestCollectedArmorPlate = player_info.find('highestCollected.ArmorPlate').text
            highestCollectedArmorReductionOnHit = player_info.find('highestCollected.ArmorReductionOnHit').text
            highestCollectedArtifactKey = player_info.find('highestCollected.ArtifactKey').text
            highestCollectedBarrierOnKill = player_info.find('highestCollected.BarrierOnKill').text
            highestCollectedBear = player_info.find('highestCollected.Bear').text
            highestCollectedBeetleGland = player_info.find('highestCollected.BeetleGland').text
            highestCollectedBleedOnHit = player_info.find('highestCollected.BleedOnHit').text
            highestCollectedBonusGoldPackOnKill = player_info.find('highestCollected.BonusGoldPackOnKill').text
            highestCollectedBossDamageBonus = player_info.find('highestCollected.BossDamageBonus').text
            highestCollectedChainLightning = player_info.find('highestCollected.ChainLightning').text
            highestCollectedCritGlasses = player_info.find('highestCollected.CritGlasses').text
            highestCollectedCrowbar = player_info.find('highestCollected.Crowbar').text
            highestCollectedDeathMark = player_info.find('highestCollected.DeathMark').text
            highestCollectedDrizzlePlayerHelper = player_info.find('highestCollected.DrizzlePlayerHelper').text
            highestCollectedEquipmentMagazine = player_info.find('highestCollected.EquipmentMagazine').text
            highestCollectedExecuteLowHealthElite = player_info.find('highestCollected.ExecuteLowHealthElite').text
            highestCollectedFallBoots = player_info.find('highestCollected.FallBoots').text
            highestCollectedFeather = player_info.find('highestCollected.Feather').text
            highestCollectedFlatHealth = player_info.find('highestCollected.FlatHealth').text
            highestCollectedHeadHunter = player_info.find('highestCollected.HeadHunter').text
            highestCollectedHealWhileSafe = player_info.find('highestCollected.HealWhileSafe').text
            highestCollectedHoof = player_info.find('highestCollected.Hoof').text
            highestCollectedIcicle = player_info.find('highestCollected.Icicle').text
            highestCollectedIgniteOnKill = player_info.find('highestCollected.IgniteOnKill').text
            highestCollectedJumpBoost = player_info.find('highestCollected.JumpBoost').text
            highestCollectedMedkit = player_info.find('highestCollected.Medkit').text
            highestCollectedMissile = player_info.find('highestCollected.Missile').text
            highestCollectedMushroom = player_info.find('highestCollected.Mushroom').text
            highestCollectedNearbyDamageBonus = player_info.find('highestCollected.NearbyDamageBonus').text
            highestCollectedNovaOnLowHealth = player_info.find('highestCollected.NovaOnLowHealth').text
            highestCollectedPersonalShield = player_info.find('highestCollected.PersonalShield').text
            highestCollectedPhasing = player_info.find('highestCollected.Phasing').text
            highestCollectedScrapWhite = player_info.find('highestCollected.ScrapWhite').text
            highestCollectedSeed = player_info.find('highestCollected.Seed').text
            highestCollectedSlowOnHit = player_info.find('highestCollected.SlowOnHit').text
            highestCollectedSprintArmor = player_info.find('highestCollected.SprintArmor').text
            highestCollectedSprintBonus = player_info.find('highestCollected.SprintBonus').text
            highestCollectedSprintOutOfCombat = player_info.find('highestCollected.SprintOutOfCombat').text
            highestCollectedStickyBomb = player_info.find('highestCollected.StickyBomb').text
            highestCollectedStunChanceOnHit = player_info.find('highestCollected.StunChanceOnHit').text
            highestCollectedSyringe = player_info.find('highestCollected.Syringe').text
            highestCollectedTPHealingNova = player_info.find('highestCollected.TPHealingNova').text
            highestCollectedThorns = player_info.find('highestCollected.Thorns').text
            highestCollectedTooth = player_info.find('highestCollected.Tooth').text
            highestCollectedTreasureCache = player_info.find('highestCollected.TreasureCache').text
            highestCollectedWardOnLevel = player_info.find('highestCollected.WardOnLevel').text
            totalTimeHeldCommandMissile = player_info.find('totalTimeHeld.CommandMissile').text
            totalTimeHeldFireBallDash = player_info.find('totalTimeHeld.FireBallDash').text
            totalTimeHeldGainArmor = player_info.find('totalTimeHeld.GainArmor').text
            totalTimeHeldLifestealOnHit = player_info.find('totalTimeHeld.LifestealOnHit').text
            totalTimeHeldSaw = player_info.find('totalTimeHeld.Saw').text
            totalTimeHeldTeamWarCry = player_info.find('totalTimeHeld.TeamWarCry').text
            totalTimesFiredCommandMissile = player_info.find('totalTimesFired.CommandMissile').text
            totalTimesFiredFireBallDash = player_info.find('totalTimesFired.FireBallDash').text
            totalTimesFiredGainArmor = player_info.find('totalTimesFired.GainArmor').text
            totalTimesFiredLifestealOnHit = player_info.find('totalTimesFired.LifestealOnHit').text
            totalTimesFiredSaw = player_info.find('totalTimesFired.Saw').text
            totalTimesFiredTeamWarCry = player_info.find('totalTimesFired.TeamWarCry').text
            totalTimesVisitedartifactworld = player_info.find('totalTimesVisited.artifactworld').text
            totalTimesVisitedbazaar = player_info.find('totalTimesVisited.bazaar').text
            totalTimesVisitedblackbeach = player_info.find('totalTimesVisited.blackbeach').text
            totalTimesVisitedfoggyswamp = player_info.find('totalTimesVisited.foggyswamp').text
            totalTimesVisitedgoolake = player_info.find('totalTimesVisited.goolake').text
            totalTimesVisitedmoon2 = player_info.find('totalTimesVisited.moon2').text
            totalTimesVisitedrootjungle = player_info.find('totalTimesVisited.rootjungle').text
            totalTimesVisitedshipgraveyard = player_info.find('totalTimesVisited.shipgraveyard').text
            totalTimesVisitedskymeadow = player_info.find('totalTimesVisited.skymeadow').text
            totalTimesVisitedwispgraveyard = player_info.find('totalTimesVisited.wispgraveyard').text
            totalTimesClearedartifactworld = player_info.find('totalTimesCleared.artifactworld').text
            totalTimesClearedbazaar = player_info.find('totalTimesCleared.bazaar').text
            totalTimesClearedblackbeach = player_info.find('totalTimesCleared.blackbeach').text
            totalTimesClearedfoggyswamp = player_info.find('totalTimesCleared.foggyswamp').text
            totalTimesClearedgoolake = player_info.find('totalTimesCleared.goolake').text
            totalTimesClearedmoon2 = player_info.find('totalTimesCleared.moon2').text
            totalTimesClearedrootjungle = player_info.find('totalTimesCleared.rootjungle').text
            totalTimesClearedshipgraveyard = player_info.find('totalTimesCleared.shipgraveyard').text
            totalTimesClearedskymeadow = player_info.find('totalTimesCleared.skymeadow').text
            totalTimesClearedwispgraveyard = player_info.find('totalTimesCleared.wispgraveyard').text
            itemAcquisitionOrder = player_info.find('itemAcquisitionOrder').text
            AlienHead = player_info.find('AlienHead').text
            ArmorPlate = player_info.find('ArmorPlate').text
            ArmorReductionOnHit = player_info.find('ArmorReductionOnHit').text
            BarrierOnKill = player_info.find('BarrierOnKill').text
            Bear = player_info.find('Bear').text
            BeetleGland = player_info.find('BeetleGland').text
            BleedOnHit = player_info.find('BleedOnHit').text
            BonusGoldPackOnKill = player_info.find('BonusGoldPackOnKill').text
            BossDamageBonus = player_info.find('BossDamageBonus').text
            ChainLightning = player_info.find('ChainLightning').text
            CritGlasses = player_info.find('CritGlasses').text
            Crowbar = player_info.find('Crowbar').text
            DeathMark = player_info.find('DeathMark').text
            DrizzlePlayerHelper = player_info.find('DrizzlePlayerHelper').text
            EquipmentMagazine = player_info.find('EquipmentMagazine').text
            ExecuteLowHealthElite = player_info.find('ExecuteLowHealthElite').text
            FallBoots = player_info.find('FallBoots').text
            Feather = player_info.find('Feather').text
            FlatHealth = player_info.find('FlatHealth').text
            HeadHunter = player_info.find('HeadHunter').text
            HealWhileSafe = player_info.find('HealWhileSafe').text
            Hoof = player_info.find('Hoof').text
            Icicle = player_info.find('Icicle').text
            IgniteOnKill = player_info.find('IgniteOnKill').text
            JumpBoost = player_info.find('JumpBoost').text
            Medkit = player_info.find('Medkit').text
            Missile = player_info.find('Missile').text
            Mushroom = player_info.find('Mushroom').text
            NearbyDamageBonus = player_info.find('NearbyDamageBonus').text
            NovaOnLowHealth = player_info.find('NovaOnLowHealth').text
            PersonalShield = player_info.find('PersonalShield').text
            Phasing = player_info.find('Phasing').text
            ScrapWhite = player_info.find('ScrapWhite').text
            Seed = player_info.find('Seed').text
            SlowOnHit = player_info.find('SlowOnHit').text
            SprintArmor = player_info.find('SprintArmor').text
            SprintBonus = player_info.find('SprintBonus').text
            SprintOutOfCombat = player_info.find('SprintOutOfCombat').text
            StickyBomb = player_info.find('StickyBomb').text
            StunChanceOnHit = player_info.find('StunChanceOnHit').text
            Syringe = player_info.find('Syringe').text
            TPHealingNova = player_info.find('TPHealingNova').text
            Thorns = player_info.find('Thorns').text
            Tooth = player_info.find('Tooth').text
            WardOnLevel = player_info.find('WardOnLevel').text
            equipment = player_info.find('equipment').text

            data.append({
                'version': version,
                'run_guid': run_guid,
                'game_mode_name': game_mode_name,
                'game_ending': game_ending,
                'seed': seed,
                'run_start_time_utc': run_start_time_utc,
                'snapshot_time_utc': snapshot_time_utc,
                'snapshot_run_time': snapshot_run_time,
                'run_stopwatch_value': run_stopwatch_value,
                'rule_book': rule_book,
                'name': name,
                'body_name': body_name,
                'killer_body_name': killer_body_name,
                'is_dead': is_dead,
                'totalGamesPlayed': totalGamesPlayed,
                'totalTimeAlive': totalTimeAlive,
                'totalKills': totalKills,
                'totalMinionKills': totalMinionKills,
                'totalDamageDealt': totalDamageDealt,
                'totalDamageTaken': totalDamageTaken,
                'totalHealthHealed': totalHealthHealed,
                'highestDamageDealt': highestDamageDealt,
                'highestLevel': highestLevel,
                'totalGoldCollected': totalGoldCollected,
                'maxGoldCollected': maxGoldCollected,
                'totalDistanceTraveled': totalDistanceTraveled,
                'totalItemsCollected': totalItemsCollected,
                'highestItemsCollected': highestItemsCollected,
                'totalStagesCompleted': totalStagesCompleted,
                'highestStagesCompleted': highestStagesCompleted,
                'totalPurchases': totalPurchases,
                'highestPurchases': highestPurchases,
                'totalGoldPurchases': totalGoldPurchases,
                'highestGoldPurchases': highestGoldPurchases,
                'totalLunarPurchases': totalLunarPurchases,
                'highestLunarPurchases': highestLunarPurchases,
                'totalTier1Purchases': totalTier1Purchases,
                'highestTier1Purchases': highestTier1Purchases,
                'totalDronesPurchased': totalDronesPurchased,
                'totalTurretsPurchased': totalTurretsPurchased,
                'totalGreenSoupsPurchased': totalGreenSoupsPurchased,
                'totalEliteKills': totalEliteKills,
                'totalTeleporterBossKillsWitnessed': totalTeleporterBossKillsWitnessed,
                'totalMaulingRockKills': totalMaulingRockKills,
                'totalTimeAlive.Bandit2Body': totalTimeAliveBandit2Body,
                'longestRun.Bandit2Body': longestRunBandit2Body,
                'damageDealtTo.BeetleBody': damageDealtToBeetleBody,
                'damageDealtTo.BeetleGuardAllyBody': damageDealtToBeetleGuardAllyBody,
                'damageDealtTo.BeetleGuardBody': damageDealtToBeetleGuardBody,
                'damageDealtTo.BeetleQueen2Bod': damageDealtToBeetleQueen2Bod,
                'damageDealtTo.BellBody': damageDealtToBellBody,
                'damageDealtTo.BrotherBody': damageDealtToBrotherBody,
                'damageDealtTo.BrotherHurtBody': damageDealtToBrotherHurtBody,
                'damageDealtTo.ClayBossBody': damageDealtToClayBossBody,
                'damageDealtTo.ClayBruiserBody': damageDealtToClayBruiserBody,
                'damageDealtTo.ExplosivePotDestructibleBody': damageDealtToExplosivePotDestructibleBody,
                'damageDealtTo.GolemBody': damageDealtToGolemBody,
                'damageDealtTo.GrandParentBody': damageDealtToGrandParentBody,
                'damageDealtTo.GravekeeperBody': damageDealtToGravekeeperBody,
                'damageDealtTo.GravekeeperTrackingFireball': damageDealtToGravekeeperTrackingFireball,
                'damageDealtTo.GreaterWispBody': damageDealtToGreaterWispBody,
                'damageDealtTo.ImpBody': damageDealtToImpBody,
                'damageDealtTo.ImpBossBody': damageDealtToImpBossBody,
                'damageDealtTo.JellyfishBody': damageDealtToJellyfishBody,
                'damageDealtTo.LemurianBody': damageDealtToLemurianBody,
                'damageDealtTo.LemurianBruiserBody': damageDealtToLemurianBruiserBody,
                'damageDealtTo.LunarExploderBody': damageDealtToLunarExploderBody,
                'damageDealtTo.LunarGolemBody': damageDealtToLunarGolemBody,
                'damageDealtTo.LunarWispBody': damageDealtToLunarWispBody,
                'damageDealtTo.MagmaWormBody': damageDealtToMagmaWormBody,
                'damageDealtTo.MiniMushroomBody': damageDealtToMiniMushroomBody,
                'damageDealtTo.NullifierBody': damageDealtToNullifierBody,
                'damageDealtTo.ParentBody': damageDealtToParentBody,
                'damageDealtTo.RoboBallBossBody': damageDealtToRoboBallBossBody,
                'damageDealtTo.RoboBallMiniBody': damageDealtToRoboBallMiniBody,
                'damageDealtTo.SMMaulingRockLarge': damageDealtToSMMaulingRockLarge,
                'damageDealtTo.SMMaulingRockMedium': damageDealtToSMMaulingRockMedium,
                'damageDealtTo.ScavBody': damageDealtToScavBody,
                'damageDealtTo.ShopkeeperBody': damageDealtToShopkeeperBody,
                'damageDealtTo.SuperRoboBallBossBody': damageDealtToSuperRoboBallBossBody,
                'damageDealtTo.TitanBody': damageDealtToTitanBody,
                'damageDealtTo.UrchinTurretBody': damageDealtToUrchinTurretBody,
                'damageDealtTo.VagrantBody': damageDealtToVagrantBody,
                'damageDealtTo.VagrantTrackingBomb': damageDealtToVagrantTrackingBomb,
                'damageDealtTo.VultureBody': damageDealtToVultureBody,
                'damageDealtTo.VultureEggBody': damageDealtToVultureEggBody,
                'damageDealtTo.WispBody': damageDealtToWispBody,
                'damageDealtAs.Bandit2Body': damageDealtAsBandit2Body,
                'minionDamageDealtAs.Bandit2Body': minionDamageDealtAsBandit2Body,
                'damageTakenFrom.ArtifactShellBody': damageTakenFromArtifactShellBody,
                'damageTakenFrom.BeetleBody': damageTakenFromBeetleBody,
                'damageTakenFrom.BeetleGuardBody': damageTakenFromBeetleGuardBody,
                'damageTakenFrom.BellBody': damageTakenFromBellBody,
                'damageTakenFrom.BrotherBody': damageTakenFromBrotherBody,
                'damageTakenFrom.BrotherHauntBody': damageTakenFromBrotherHauntBody,
                'damageTakenFrom.BrotherHurtBody': damageTakenFromBrotherHurtBody,
                'damageTakenFrom.ClayBossBody': damageTakenFromClayBossBody,
                'damageTakenFrom.ClayBruiserBody': damageTakenFromClayBruiserBody,
                'damageTakenFrom.GolemBody': damageTakenFromGolemBody,
                'damageTakenFrom.GravekeeperBody': damageTakenFromGravekeeperBody,
                'damageTakenFrom.GreaterWispBody': damageTakenFromGreaterWispBody,
                'damageTakenFrom.JellyfishBody': damageTakenFromJellyfishBody,
                'damageTakenFrom.LemurianBody': damageTakenFromLemurianBody,
                'damageTakenFrom.LemurianBruiserBody': damageTakenFromLemurianBruiserBody,
                'damageTakenFrom.LunarExploderBody': damageTakenFromLunarExploderBody,
                'damageTakenFrom.LunarWispBody': damageTakenFromLunarWispBody,
                'damageTakenFrom.MagmaWormBody': damageTakenFromMagmaWormBody,
                'damageTakenFrom.MiniMushroomBody': damageTakenFromMiniMushroomBody,
                'damageTakenFrom.NullifierBody': damageTakenFromNullifierBody,
                'damageTakenFrom.ParentBody': damageTakenFromParentBody,
                'damageTakenFrom.RoboBallMiniBody': damageTakenFromRoboBallMiniBody,
                'damageTakenFrom.ScavBody': damageTakenFromScavBody,
                'damageTakenFrom.SuperRoboBallBossBody': damageTakenFromSuperRoboBallBossBody,
                'damageTakenFrom.VagrantBody': damageTakenFromVagrantBody,
                'damageTakenFrom.VultureBody': damageTakenFromVultureBody,
                'damageTakenFrom.WispBody': damageTakenFromWispBody,
                'damageTakenAs.Bandit2Body': damageTakenAsBandit2Body,
                'killsAgainst.BeetleBody': killsAgainstBeetleBody,
                'killsAgainst.BeetleGuardBody': killsAgainstBeetleGuardBody,
                'killsAgainst.BeetleQueen2Body': killsAgainstBeetleQueen2Body,
                'killsAgainst.BellBody': killsAgainstBellBody,
                'killsAgainst.ClayBossBody': killsAgainstClayBossBody,
                'killsAgainst.ClayBruiserBody': killsAgainstClayBruiserBody,
                'killsAgainst.ExplosivePotDestructibleBody': killsAgainstExplosivePotDestructibleBody,
                'killsAgainst.GolemBody': killsAgainstGolemBody,
                'killsAgainst.GrandParentBody': killsAgainstGrandParentBody,
                'killsAgainst.GravekeeperBody': killsAgainstGravekeeperBody,
                'killsAgainst.GreaterWispBody': killsAgainstGreaterWispBody,
                'killsAgainst.ImpBody': killsAgainstImpBody,
                'killsAgainst.ImpBossBody': killsAgainstImpBossBody,
                'killsAgainst.JellyfishBody': killsAgainstJellyfishBody,
                'killsAgainst.LemurianBody': killsAgainstLemurianBody,
                'killsAgainst.LemurianBruiserBody': killsAgainstLemurianBruiserBody,
                'killsAgainst.LunarExploderBody': killsAgainstLunarExploderBody,
                'killsAgainst.LunarGolemBody': killsAgainstLunarGolemBody,
                'killsAgainst.LunarWispBody': killsAgainstLunarWispBody,
                'killsAgainst.MagmaWormBody': killsAgainstMagmaWormBody,
                'killsAgainst.MiniMushroomBody': killsAgainstMiniMushroomBody,
                'killsAgainst.NullifierBody': killsAgainstNullifierBody,
                'killsAgainst.ParentBody': killsAgainstParentBody,
                'killsAgainst.RoboBallBossBody': killsAgainstRoboBallBossBody,
                'killsAgainst.RoboBallMiniBody': killsAgainstRoboBallMiniBody,
                'killsAgainst.SMMaulingRockLarge': killsAgainstSMMaulingRockLarge,
                'killsAgainst.SMMaulingRockMedium': killsAgainstSMMaulingRockMedium,
                'killsAgainst.ScavBody': killsAgainstScavBody,
                'killsAgainst.SuperRoboBallBossBody': killsAgainstSuperRoboBallBossBody,
                'killsAgainst.TitanBody': killsAgainstTitanBody,
                'killsAgainst.UrchinTurretBody': killsAgainstUrchinTurretBody,
                'killsAgainst.VagrantBody': killsAgainstVagrantBody,
                'killsAgainst.VagrantTrackingBomb': killsAgainstVagrantTrackingBomb,
                'killsAgainst.VultureBody': killsAgainstVultureBody,
                'killsAgainst.VultureEggBody': killsAgainstVultureEggBody,
                'killsAgainst.WispBody': killsAgainstWispBody,
                'killsAgainstElite.BeetleBody': killsAgainstEliteBeetleBody,
                'killsAgainstElite.BellBody': killsAgainstEliteBellBody,
                'killsAgainstElite.GolemBody': killsAgainstEliteGolemBody,
                'killsAgainstElite.ImpBody': killsAgainstEliteImpBody,
                'killsAgainstElite.JellyfishBody': killsAgainstEliteJellyfishBody,
                'killsAgainstElite.LemurianBody': killsAgainstEliteLemurianBody,
                'killsAgainstElite.LunarExploderBody': killsAgainstEliteLunarExploderBody,
                'killsAgainstElite.MiniMushroomBody': killsAgainstEliteMiniMushroomBody,
                'killsAgainstElite.VultureBody': killsAgainstEliteVultureBody,
                'killsAgainstElite.WispBody': killsAgainstEliteWispBody,
                'killsAs.Bandit2Body': killsAsBandit2Body,
                'minionKillsAs.Bandit2Body': minionKillsAsBandit2Body,
                'timesPicked.Bandit2Body': timesPickedBandit2Body,
                'totalCollected.AlienHead': totalCollectedAlienHead,
                'totalCollected.ArmorPlate': totalCollectedArmorPlate,
                'totalCollected.ArmorReductionOnHit': totalCollectedArmorReductionOnHit,
                'totalCollected.ArtifactKey': totalCollectedArtifactKey,
                'totalCollected.BarrierOnKill': totalCollectedBarrierOnKill,
                'totalCollected.Bear': totalCollectedBear,
                'totalCollected.BeetleGland': totalCollectedBeetleGland,
                'totalCollected.BleedOnHit': totalCollectedBleedOnHit,
                'totalCollected.BonusGoldPackOnKill': totalCollectedBonusGoldPackOnKill,
                'totalCollected.BossDamageBonus': totalCollectedBossDamageBonus,
                'totalCollected.ChainLightning': totalCollectedChainLightning,
                'totalCollected.CritGlasses': totalCollectedCritGlasses,
                'totalCollected.Crowbar': totalCollectedCrowbar,
                'totalCollected.DeathMark': totalCollectedDeathMark,
                'totalCollected.DrizzlePlayerHelper': totalCollectedDrizzlePlayerHelper,
                'totalCollected.EquipmentMagazine': totalCollectedEquipmentMagazine,
                'totalCollected.ExecuteLowHealthElite': totalCollectedExecuteLowHealthElite,
                'totalCollected.FallBoots': totalCollectedFallBoots,
                'totalCollected.Feather': totalCollectedFeather,
                'totalCollected.FlatHealth': totalCollectedFlatHealth,
                'totalCollected.HeadHunter': totalCollectedHeadHunter,
                'totalCollected.HealWhileSafe': totalCollectedHealWhileSafe,
                'totalCollected.Hoof': totalCollectedHoof,
                'totalCollected.Icicle': totalCollectedIcicle,
                'totalCollected.IgniteOnKill': totalCollectedIgniteOnKill,
                'totalCollected.JumpBoost': totalCollectedJumpBoost,
                'totalCollected.Medkit': totalCollectedMedkit,
                'totalCollected.Missile': totalCollectedMissile,
                'totalCollected.Mushroom': totalCollectedMushroom,
                'totalCollected.NearbyDamageBonus': totalCollectedNearbyDamageBonus,
                'totalCollected.NovaOnLowHealth': totalCollectedNovaOnLowHealth,
                'totalCollected.PersonalShield': totalCollectedPersonalShield,
                'totalCollected.Phasing': totalCollectedPhasing,
                'totalCollected.ScrapWhite': totalCollectedScrapWhite,
                'totalCollected.Seed': totalCollectedSeed,
                'totalCollected.SlowOnHit': totalCollectedSlowOnHit,
                'totalCollected.SprintArmor': totalCollectedSprintArmor,
                'totalCollected.SprintBonus': totalCollectedSprintBonus,
                'totalCollected.SprintOutOfCombat': totalCollectedSprintOutOfCombat,
                'totalCollected.StickyBomb': totalCollectedStickyBomb,
                'totalCollected.StunChanceOnHit': totalCollectedStunChanceOnHit,
                'totalCollected.Syringe': totalCollectedSyringe,
                'totalCollected.TPHealingNova': totalCollectedTPHealingNova,
                'totalCollected.Thorns': totalCollectedThorns,
                'totalCollected.Tooth': totalCollectedTooth,
                'totalCollected.TreasureCache': totalCollectedTreasureCache,
                'totalCollected.WardOnLevel': totalCollectedWardOnLevel,
                'highestCollected.AlienHead': highestCollectedAlienHead,
                'highestCollected.ArmorPlate': highestCollectedArmorPlate,
                'highestCollected.ArmorReductionOnHit': highestCollectedArmorReductionOnHit,
                'highestCollected.ArtifactKey': highestCollectedArtifactKey,
                'highestCollected.BarrierOnKill': highestCollectedBarrierOnKill,
                'highestCollected.Bear': highestCollectedBear,
                'highestCollected.BeetleGland': highestCollectedBeetleGland,
                'highestCollected.BleedOnHit': highestCollectedBleedOnHit,
                'highestCollected.BonusGoldPackOnKill': highestCollectedBonusGoldPackOnKill,
                'highestCollected.BossDamageBonus': highestCollectedBossDamageBonus,
                'highestCollected.ChainLightning': highestCollectedChainLightning,
                'highestCollected.CritGlasses': highestCollectedCritGlasses,
                'highestCollected.Crowbar': highestCollectedCrowbar,
                'highestCollected.DeathMark': highestCollectedDeathMark,
                'highestCollected.DrizzlePlayerHelper': highestCollectedDrizzlePlayerHelper,
                'highestCollected.EquipmentMagazine': highestCollectedEquipmentMagazine,
                'highestCollected.ExecuteLowHealthElite': highestCollectedExecuteLowHealthElite,
                'highestCollected.FallBoots': highestCollectedFallBoots,
                'highestCollected.Feather': highestCollectedFeather,
                'highestCollected.FlatHealth': highestCollectedFlatHealth,
                'highestCollected.HeadHunter': highestCollectedHeadHunter,
                'highestCollected.HealWhileSafe': highestCollectedHealWhileSafe,
                'highestCollected.Hoof': highestCollectedHoof,
                'highestCollected.Icicle': highestCollectedIcicle,
                'highestCollected.IgniteOnKill': highestCollectedIgniteOnKill,
                'highestCollected.JumpBoost': highestCollectedJumpBoost,
                'highestCollected.Medkit': highestCollectedMedkit,
                'highestCollected.Missile': highestCollectedMissile,
                'highestCollected.Mushroom': highestCollectedMushroom,
                'highestCollected.NearbyDamageBonus': highestCollectedNearbyDamageBonus,
                'highestCollected.NovaOnLowHealth': highestCollectedNovaOnLowHealth,
                'highestCollected.PersonalShield': highestCollectedPersonalShield,
                'highestCollected.Phasing': highestCollectedPhasing,
                'highestCollected.ScrapWhite': highestCollectedScrapWhite,
                'highestCollected.Seed': highestCollectedSeed,
                'highestCollected.SlowOnHit': highestCollectedSlowOnHit,
                'highestCollected.SprintArmor': highestCollectedSprintArmor,
                'highestCollected.SprintBonus': highestCollectedSprintBonus,
                'highestCollected.SprintOutOfCombat': highestCollectedSprintOutOfCombat,
                'highestCollected.StickyBomb': highestCollectedStickyBomb,
                'highestCollected.StunChanceOnHit': highestCollectedStunChanceOnHit,
                'highestCollected.Syringe': highestCollectedSyringe,
                'highestCollected.TPHealingNova': highestCollectedTPHealingNova,
                'highestCollected.Thorns': highestCollectedThorns,
                'highestCollected.Tooth': highestCollectedTooth,
                'highestCollected.TreasureCache': highestCollectedTreasureCache,
                'highestCollected.WardOnLevel': highestCollectedWardOnLevel,
                'totalTimeHeld.CommandMissile': totalTimeHeldCommandMissile,
                'totalTimeHeld.FireBallDash': totalTimeHeldFireBallDash,
                'totalTimeHeld.GainArmor': totalTimeHeldGainArmor,
                'totalTimeHeld.LifestealOnHit': totalTimeHeldLifestealOnHit,
                'totalTimeHeld.Saw': totalTimeHeldSaw,
                'totalTimeHeld.TeamWarCry': totalTimeHeldTeamWarCry,
                'totalTimesFired.CommandMissile': totalTimesFiredCommandMissile,
                'totalTimesFired.FireBallDash': totalTimesFiredFireBallDash,
                'totalTimesFired.GainArmor': totalTimesFiredGainArmor,
                'totalTimesFired.LifestealOnHit': totalTimesFiredLifestealOnHit,
                'totalTimesFired.Saw': totalTimesFiredSaw,
                'totalTimesFired.TeamWarCry': totalTimesFiredTeamWarCry,
                'totalTimesVisited.artifactworld': totalTimesVisitedartifactworld,
                'totalTimesVisited.bazaar': totalTimesVisitedbazaar,
                'totalTimesVisited.blackbeach': totalTimesVisitedblackbeach,
                'totalTimesVisited.foggyswamp': totalTimesVisitedfoggyswamp,
                'totalTimesVisited.goolake': totalTimesVisitedgoolake,
                'totalTimesVisited.moon2': totalTimesVisitedmoon2,
                'totalTimesVisited.rootjungle': totalTimesVisitedrootjungle,
                'totalTimesVisited.shipgraveyard': totalTimesVisitedshipgraveyard,
                'totalTimesVisited.skymeadow': totalTimesVisitedskymeadow,
                'totalTimesVisited.wispgraveyard': totalTimesVisitedwispgraveyard,
                'totalTimesCleared.artifactworld': totalTimesClearedartifactworld,
                'totalTimesCleared.bazaar': totalTimesClearedbazaar,
                'totalTimesCleared.blackbeach': totalTimesClearedblackbeach,
                'totalTimesCleared.foggyswamp': totalTimesClearedfoggyswamp,
                'totalTimesCleared.goolake': totalTimesClearedgoolake,
                'totalTimesCleared.moon2': totalTimesClearedmoon2,
                'totalTimesCleared.rootjungle': totalTimesClearedrootjungle,
                'totalTimesCleared.shipgraveyard': totalTimesClearedshipgraveyard,
                'totalTimesCleared.skymeadow': totalTimesClearedskymeadow,
                'totalTimesCleared.wispgraveyard': totalTimesClearedwispgraveyard,
                'itemAcquisitionOrder': itemAcquisitionOrder,
                'AlienHead': AlienHead,
                'ArmorPlate': ArmorPlate,
                'ArmorReductionOnHit': ArmorReductionOnHit,
                'BarrierOnKill': BarrierOnKill,
                'Bear': Bear,
                'BeetleGland': BeetleGland,
                'BleedOnHit': BleedOnHit,
                'BonusGoldPackOnKill': BonusGoldPackOnKill,
                'BossDamageBonus': BossDamageBonus,
                'ChainLightning': ChainLightning,
                'CritGlasses': CritGlasses,
                'Crowbar': Crowbar,
                'DeathMark': DeathMark,
                'DrizzlePlayerHelper': DrizzlePlayerHelper,
                'EquipmentMagazine': EquipmentMagazine,
                'ExecuteLowHealthElite': ExecuteLowHealthElite,
                'FallBoots': FallBoots,
                'Feather': Feather,
                'FlatHealth': FlatHealth,
                'HeadHunter': HeadHunter,
                'HealWhileSafe': HealWhileSafe,
                'Hoof': Hoof,
                'Icicle': Icicle,
                'IgniteOnKill': IgniteOnKill,
                'JumpBoost': JumpBoost,
                'Medkit': Medkit,
                'Missile': Missile,
                'Mushroom': Mushroom,
                'NearbyDamageBonus': NearbyDamageBonus,
                'NovaOnLowHealth': NovaOnLowHealth,
                'PersonalShield': PersonalShield,
                'Phasing': Phasing,
                'ScrapWhite': ScrapWhite,
                'Seed': Seed,
                'SlowOnHit': SlowOnHit,
                'SprintArmor': SprintArmor,
                'SprintBonus': SprintBonus,
                'SprintOutOfCombat': SprintOutOfCombat,
                'StickyBomb': StickyBomb,
                'StunChanceOnHit': StunChanceOnHit,
                'Syringe': Syringe,
                'TPHealingNova': TPHealingNova,
                'Thorns': Thorns,
                'Tooth': Tooth,
                'WardOnLevel': WardOnLevel,
                'equipment': equipment
            })
            
    else:
        print(f"XML file '{xml_filename}.xml' not found in the folder.")
# Out:
# XML file 'gameModeName.xml' not found in the folder.
# XML file 'gameEnding.xml' not found in the folder.
# XML file 'seed.xml' not found in the folder.
# XML file 'runStartTimeUtc.xml' not found in the folder.
# XML file 'snapshotTimeUtc.xml' not found in the folder.
# XML file 'snapshotRunTime.xml' not found in the folder.
# XML file 'runStopwatchValue.xml' not found in the folder.
# XML file 'ruleBook.xml' not found in the folder.
# XML file 'name.xml' not found in the folder.
# XML file 'bodyName.xml' not found in the folder.
# XML file 'killerBodyName.xml' not found in the folder.
# XML file 'isDead.xml' not found in the folder.
# XML file 'totalGamesPlayed.xml' not found in the folder.
# XML file 'totalTimeAlive.xml' not found in the folder.
# XML file 'totalKills.xml' not found in the folder.
# XML file 'totalMinionKills.xml' not found in the folder.
# XML file 'totalDamageDealt.xml' not found in the folder.
# XML file 'totalDamageTaken.xml' not found in the folder.
# ...
